# %%
import pandas as pd
from repos.api_request import fetch_data
# Out:
# API response received successfully
# Fetching data for GOOGL from Alpha Vantage
# API response received successfully
# Fetching data for IBM from Alpha Vantage
# API response received successfully

# %%
stocks = ["AAPL", "MSFT", "GOOGL", "IBM"]
for stock in stocks:
    data = fetch_data(stock)
# Out:
# Fetching data for AAPL from Alpha Vantage
# API response received successfully
# Fetching data for MSFT from Alpha Vantage
# API response received successfully
# Fetching data for GOOGL from Alpha Vantage
# API response received successfully
# Fetching data for IBM from Alpha Vantage
# API response received successfully
